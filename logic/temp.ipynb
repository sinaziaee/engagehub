# %%
import pandas as pd
df = pd.read_csv('form_responses.csv')
df.head()
# Out:
#   age_group gender neighborhood     visit_frequency  \
# 0     35–44   Male   Beltline\n  A few times a year
# 1     25–34   Male   Beltline\n               Daily
#
#                 parks_visited              purpose travel_method  \
# 0  Fish Creek Provincial Park  Picnicking/Relaxing       Walking
# 1              Nose Hill Park          Dog walking       Walking
#
#    cleanliness_rating  safety_rating       accessibility amenities_used  \
# 0                   5              5  Very accessible.\n          Other
# 1                   2              5  Very accessible.\n   Picnic areas
#
#                improvements events_participated              event_experience  \
# 0      More shaded areas.\n                 Yes  Enjoyable and informative.\n
# 1  More shade structures.\n                 Yes  Enjoyable and informative.\n
#
#     concerns comments
# 0  Crowds.\n    No.\n
# 1  Crowds.\n  None.\n
